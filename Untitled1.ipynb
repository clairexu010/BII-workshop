# %% [markdown]
# <a href="https://colab.research.google.com/github/clairexu010/BII-workshop/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
ls
# Out:
# Chest_XRay.jpg  sample_data/

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-deabeaea-15c1-48c1-86bb-92a2597d44e5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-deabeaea-15c1-48c1-86bb-92a2597d44e5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
img = cv2.imread('Chest_XRay.jpg')

# %%
print(img.shape)
# Out:
# (1024, 1024, 3)

# %%
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(img)

# %%
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
print(gray_img.shape)
# Out:
# (1024, 1024)

# %%
print(type(gray_img))
# Out:
# <class 'numpy.ndarray'>

# %%
plt.imshow(gray_img)

# %%
print(gray_img[511,511]) #check the value for the position of 512,512
# Out:
# 242

# %%
cv2.imwrite('chestxray_gray.jpg', gray_img)
# Out:
# True

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-4432c45a-0cd4-4721-a4cf-1a03d09eaad9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4432c45a-0cd4-4721-a4cf-1a03d09eaad9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving totoro.jpeg to totoro.jpeg

# %%
img = cv2.imread('totoro.jpeg')

# %%
plt.imshow(img)

# %%
gray_img_totoro = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray_img_totoro)

# %%
print(img.shape)
# Out:
# (1401, 1000, 3)

# %%
print(gray_img_totoro.shape)
# Out:
# (1401, 1000)

# %%
print(type(img))
print(type(gray_img_totoro))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
print(gray_img_totoro[500,500])
# Out:
# 147

# %%
print(gray_img.min())
print(gray_img.max())
# Out:
# 0
# 255

# %%
cv2.imwrite('totoro_gray.jpg', gray_img_totoro)
# Out:
# True

# %%
height, width = gray_img.shape
print(height, width)
print(height * width *1)
# Out:
# 1024 1024
# 1048576

# %%
rotationMatrix = cv2.getRotationMatrix2D((width/2, height/2), -30, 0.5)

rotatedImage = cv2.warpAffine(img, rotationMatrix, (width, height))

# %%
plt.subplot(1,2,1)
plt.imshow(img)
plt.title("'Orginial Image")

plt.subplot(1,2,2)
plt.imshow(rotatedImage)
plt.title("'Rotated image'")
# Out:
# Text(0.5, 1.0, "'Rotated image'")

# %%
rotationMatrix = cv2.getRotationMatrix2D((width/2, height/2), -30, 1)

rotatedImage = cv2.warpAffine(img, rotationMatrix, (3*width, 2*height))

# %%
plt.subplot(1,2,1)
plt.imshow(img)
plt.title("'Orginial Image")

plt.subplot(1,2,2)
plt.imshow(rotatedImage)
plt.title("'Rotated image'")
# Out:
# Text(0.5, 1.0, "'Rotated image'")

# %%
plt.imshow(rotatedImage)
plt.title("'Rotated image'")
# Out:
# Text(0.5, 1.0, "'Rotated image'")

# %%
newImg = cv2.resize(img, (0,0), fx=0.5, fy=0.5) #scaling is part of resizing. resizing can both keep and change the dimension of the image. if keep the original ratio of x and y, it is scaling.

# %%
plt.subplot(1,2,1)
plt.imshow(img)
plt.title("'Orginial Image")

plt.subplot(1,2,2)
plt.imshow(newImg)
plt.title("'Resize image'")
# Out:
# Text(0.5, 1.0, "'Resize image'")

# %%
newImg = cv2.resize(img, (256,512)) 
plt.subplot(1,2,1)
plt.imshow(img)
plt.title("'Orginial Image")

plt.subplot(1,2,2)
plt.imshow(newImg)
plt.title("'Resize image'")
# Out:
# Text(0.5, 1.0, "'Resize image'")

# %%
height = 128
width = 256
rotationMatrix = cv2.getRotationMatrix2D((256, 0), 0, 2)

newImg_size = cv2.resize(img, (128,256)) 

#rotatedImage = cv2.warpAffine(img, rotationMatrix, (width, height))

newImg = cv2.resize(img, (128,256)) 
newImg_rescale = cv2.resize(newImg, (0,0), fx=2, fy=2)


plt.subplot(2,2,1)
plt.imshow(img)
plt.title("'Orginial Image")

plt.subplot(2,2,2)
plt.imshow(newImg)
plt.title("'Resize image'")

plt.subplot(2,2,3)
plt.imshow(newImg_rescale)
plt.title("'Resize + Rescale'")


plt.subplot(2,2,4)
plt.imshow(newImg_resize)
plt.title("'Resize512'")

# orginal, resize, resize + rescale
# Out:
# Text(0.5, 1.0, "'Resize512'")

# %%
# Out:
# (256, 256, 3)
# (256, 128, 3)
# (1024, 1024, 3)
